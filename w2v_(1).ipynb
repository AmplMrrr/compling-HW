# %% [markdown]
# <a href="https://colab.research.google.com/github/AmplMrrr/compling-HW/blob/main/w2v_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Word2Vec** - алгоритм для создания векторных представлений слов на основе их дистрибутивных свойств
#
# **Две архитектуры:**
# - **CBOW (Continuous Bag-of-Words)**: предсказывает центральное слово по контексту
# - **Skip-Gram**: предсказывает контекстные слова по центральному слову
#
# **Ключевые параметры:**
# - `vector_size`: размерность векторов
# - `window`: размер контекстного окна
# - `min_count`: минимальная частота слова
# - `workers`: количество ядер для обучения
# - `sg`: архитектура (0 = CBOW, 1 = Skip-Gram)

# %%
# !pip install nltk
import nltk
from nltk.corpus import brown
from IPython.display import clear_output

nltk.download('brown')
nltk.download('punkt')
clear_output()

sentences = brown.sents()

print(f"Общее количество предложений: {len(sentences):,}")
print(f"Общее количество слов: {len(brown.words()):,}")
print(f"Размер словаря: {len(set(brown.words())):,}")
print(f"Категории текстов: {brown.categories()}")
# Out:
# Общее количество предложений: 57,340
# Общее количество слов: 1,161,192
# Размер словаря: 56,057
# Категории текстов: ['adventure', 'belles_lettres', 'editorial', 'fiction', 'government', 'hobbies', 'humor', 'learned', 'lore', 'mystery', 'news', 'religion', 'reviews', 'romance', 'science_fiction']

# %% [markdown]
# ### **Описание Brown Corpus:**
# - **Первый компьютерный корпус английского языка** (1964)
# - **500 текстов** по ~2000 слов каждый
# - **Жанры**: новости, художественная литература, научные тексты
# - **Сбалансированный** по жанрам и темам

# %% [markdown]
# ### **Предобработка:**
# - Использование `str.maketrans()` для удаления пунктуации
# - Фильтрация слов длиной > 1 символа (убирает артикли "a" и т.д.)
# - Минимальная длина предложения = 3 слова для задания контекста

# %%
# !pip install gensim

from gensim.models import Word2Vec
import string

# Предобработка с использованием готовых инструментов
def preprocess_text(sentences, sample_size=10000):
    processed_sentences = []

    # Создаем транслятор для удаления пунктуации
    translator = str.maketrans('', '', string.punctuation)

    for sentence in sentences[:sample_size]:
        # Приводим к нижнему регистру и удаляем пунктуацию
        cleaned = [word.lower().translate(translator) for word in sentence]

        # Убираем пустые строки и оставляем только слова
        words = [word for word in cleaned if word.isalpha() and len(word) > 1]

        # Фильтруем слишком короткие предложения
        if len(words) >= 3:  # Минимум 3 слова для контекста
            processed_sentences.append(words)

    return processed_sentences

# Обрабатываем предложения
processed_sentences = preprocess_text(sentences, sample_size=55000)
print(f"Обработано предложений: {len(processed_sentences):,}")
print(f"Пример обработанного предложения: {processed_sentences[150]}")
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.12/dist-packages (4.4.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.5.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.0.1)
# Обработано предложений: 52,357
# Пример обработанного предложения: ['the', 'bills', 'defenders', 'were', 'mostly', 'smalltown', 'legislators', 'like', 'buchanan', 'of', 'dumas', 'eligio', 'kika', 'de', 'la', 'garza', 'of', 'mission', 'sam', 'collins', 'of', 'newton', 'and', 'joe', 'chapman', 'of', 'sulphur', 'springs']

# %%
nltk.download('stopwords')

# Функция для удаления стоп слов
def remove_stopwords(sentences):
    """
    Удаляет стоп-слова из предложений
    """
    from nltk.corpus import stopwords

    # Загружаем стоп-слова для английского
    stop_words = set(stopwords.words('english'))
    print(stop_words)
    processed_sentences = []
    for sentence in sentences:
        # Убираем стоп-слова
        filtered_sentence = [word for word in sentence if word not in stop_words]
        processed_sentences.append(filtered_sentence)

    return processed_sentences

# Удаляем стоп-слова
sentences_without_stopwords = remove_stopwords(processed_sentences)

sentences_without_stopwords[150]
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# {'just', 'my', 'than', 'he', 'should', 'from', 'above', 'hadn', 'most', 'have', "you've", 'once', 'any', 'very', 'nor', 'all', 'him', 'how', "didn't", 'below', "mustn't", "she'd", 'has', 'ain', 'but', "shouldn't", "haven't", 'o', 'so', 'its', 'before', "wasn't", 'then', "it's", 'll', 'shan', "we've", 'at', 'doesn', 'against', 'as', 'couldn', 'or', 'ours', "they've", 'this', 'yours', 'in', 'who', 'off', 'we', 'weren', 'up', 'same', 'm', "needn't", 'been', 'having', 's', 'of', 'ma', "it'll", 'their', "they'll", 'a', 'haven', "we'd", "you'd", "he'll", 'his', 'was', 't', "i've", "we're", 'over', "i'll", 'yourself', 'don', 'hasn', 'when', 'y', 'only', 'through', 'herself', 'and', 'these', 'does', 'had', "weren't", 'where', 'our', 'while', 'your', 'will', 'is', 're', 'her', 'am', 'it', 'for', 'further', 'wasn', 'other', 'each', 'aren', "he'd", 'not', 'by', 'out', 'are', 'because', 'did', 'doing', 'were', 'again', 'with', 'there', 'after', 'mightn', 'few', "he's", "doesn't", 'she', 'itself', 'do', 'whom', 'what', 'those', "that'll", 'an', "they're", 'here', 'until', "shan't", "wouldn't", 'now', 'they', 'about', 'own', 'both', 'theirs', "hasn't", "mightn't", 'd', 'on', 've', 'why', "aren't", 'needn', 'such', 'mustn', 'i', 'me', 'them', 'being', "don't", 'no', 'between', "should've", "you're", 'can', 'if', 'didn', 'more', "i'm", 'myself', "they'd", 'to', 'that', "hadn't", 'you', "won't", "it'd", 'be', 'too', 'some', 'shouldn', "isn't", 'ourselves', 'won', 'down', 'themselves', 'under', "we'll", "couldn't", 'during', 'yourselves', "she's", 'himself', 'isn', "you'll", "she'll", 'which', 'the', 'wouldn', "i'd", 'into', 'hers'}
# ['bills',
#  'defenders',
#  'mostly',
#  'smalltown',
#  'legislators',
#  'like',
#  'buchanan',
#  'dumas',
#  'eligio',
#  'kika',
#  'de',
#  'la',
#  'garza',
#  'mission',
#  'sam',
#  'collins',
#  'newton',
#  'joe',
#  'chapman',
#  'sulphur',
#  'springs']

# %%
skipgram_model = Word2Vec(
    sentences=sentences_without_stopwords,
    vector_size=150,      # размерность векторов
    window=3,             # размер контекстного окна
    min_count=2,          # минимальная частота слова
    workers=4,            # количество ядер
    sg=1                  # 1 = Skip-Gram
)

print(f"Размер словаря: {len(skipgram_model.wv.key_to_index)}")
# Out:
# Размер словаря: 25967

# %%
# Обучаем CBOW модель
cbow_model = Word2Vec(
    sentences=sentences_without_stopwords,
    vector_size=200,      # размерность векторов
    window=4,             # размер контекстного окна
    min_count=2,          # минимальная частота слова
    workers=4,            # количество ядер
    sg=0                  # 0 = CBOW, 1 = Skip-Gram
)

print(f"Размер словаря: {len(cbow_model.wv.key_to_index)}")
# Out:
# Размер словаря: 25967

# %%
def compare_models(word, topn=10):
    print(f"\nПохожие слова для слова '{word}'")

    try:
        print("\nCBOW похожие слова:")
        cbow_similar = cbow_model.wv.most_similar(word, topn=topn)
        for similar_word, score in cbow_similar:
            print(f"  {similar_word}: {score:.3f}")
    except KeyError:
        print(f"  Слово '{word}' не найдено в CBOW модели")

    try:
        print("\nSkip-Gram похожие слова:")
        skipgram_similar = skipgram_model.wv.most_similar(word, topn=topn)
        for similar_word, score in skipgram_similar:
            print(f"  {similar_word}: {score:.3f}")
    except KeyError:
        print(f"  Слово '{word}' не найдено в Skip-Gram модели")

# %%
# Тестируем на разных словах
test_words = ['king', 'woman', 'city', 'water', 'good']
for word in test_words:
    compare_models(word)
# Out:
# Похожие слова для слова 'king'
#
# CBOW похожие слова:
#   planned: 1.000
#   james: 1.000
#   making: 1.000
#   created: 1.000
#   announced: 1.000
#   rising: 1.000
#   george: 1.000
#   joseph: 1.000
#   procedures: 1.000
#   drawn: 1.000
#
# Skip-Gram похожие слова:
#   queen: 0.993
#   mention: 0.990
#   sharpe: 0.990
#   baker: 0.990
#   arthur: 0.989
#   kowalski: 0.989
#   meeker: 0.989
#   sister: 0.989
#   essay: 0.988
#   johns: 0.988
#
# Похожие слова для слова 'woman'
#
# CBOW похожие слова:
#   ive: 1.000
#   boy: 0.999
#   known: 0.999
#   theres: 0.999
#   girl: 0.999
#   seen: 0.999
#   moment: 0.999
#   happened: 0.999
#   looks: 0.999
#   saw: 0.999
#
# Skip-Gram похожие слова:
#   girl: 0.969
#   wife: 0.964
#   boy: 0.957
#   father: 0.955
#   friend: 0.954
#   big: 0.952
#   dead: 0.947
#   gone: 0.943
#   looking: 0.937
#   beautiful: 0.934
#
# Похожие слова для слова 'city'
#
# CBOW похожие слова:
#   central: 0.997
#   herald: 0.996
#   yankees: 0.995
#   tribune: 0.995
#   kansas: 0.995
#   philharmonic: 0.995
#   members: 0.994
#   suburb: 0.994
#   pennsylvania: 0.994
#   somers: 0.993
#
# Skip-Gram похожие слова:
#   central: 0.917
#   york: 0.913
#   university: 0.884
#   washington: 0.880
#   yankees: 0.879
#   kansas: 0.876
#   england: 0.872
#   chicago: 0.865
#   county: 0.865
#   orleans: 0.861
#
# Похожие слова для слова 'water'
#
# CBOW похожие слова:
#   surface: 0.999
#   cut: 0.999
#   value: 0.999
#   temperature: 0.999
#   radiation: 0.999
#   knife: 0.999
#   tension: 0.999
#   clay: 0.999
#   scale: 0.999
#   distance: 0.999
#
# Skip-Gram похожие слова:
#   temperature: 0.934
#   air: 0.928
#   low: 0.922
#   light: 0.921
#   surface: 0.919
#   deep: 0.918
#   cut: 0.915
#   blue: 0.913
#   knife: 0.912
#   green: 0.910
#
# Похожие слова для слова 'good'
#
# CBOW похожие слова:
#   might: 0.998
#   little: 0.998
#   take: 0.998
#   say: 0.997
#   thing: 0.997
#   didnt: 0.997
#   way: 0.997
#   knew: 0.997
#   something: 0.997
#   look: 0.997
#
# Skip-Gram похожие слова:
#   yet: 0.944
#   child: 0.941
#   always: 0.933
#   theres: 0.931
#   id: 0.931
#   happened: 0.928
#   wasnt: 0.928
#   job: 0.927
#   sort: 0.927
#   knows: 0.926

# %%
import pandas as pd

def calculate_similarities(word_pairs):
    """Вычисляет косинусное сходство для пар слов в обеих моделях"""
    results = []

    for word1, word2 in word_pairs:
        try:
            cbow_sim = cbow_model.wv.similarity(word1, word2)
            skipgram_sim = skipgram_model.wv.similarity(word1, word2)
            results.append({
                'word_pair': f"{word1}-{word2}",
                'cbow_similarity': round(cbow_sim, 4),
                'skipgram_similarity': round(skipgram_sim, 4),
                'difference': round(abs(cbow_sim - skipgram_sim), 4)
            })
        except KeyError as e:
            print(f"Пропущена пара {word1}-{word2}: {e}")

    return pd.DataFrame(results)

# Тестовые пары слов
word_pairs = [
    ('king', 'queen'),
    ('man', 'woman'),
    ('paris', 'france'),
    ('water', 'river'),
    ('good', 'bad'),
    ('computer', 'technology')
]

similarity_df = calculate_similarities(word_pairs)
print("Сравнение косинусного сходства:")
print(similarity_df)
# Out:
# Сравнение косинусного сходства:
#              word_pair  cbow_similarity  skipgram_similarity  difference
# 0           king-queen           0.9993               0.9926      0.0067
# 1            man-woman           0.9775               0.8637      0.1138
# 2         paris-france           0.9967               0.9216      0.0750
# 3          water-river           0.9958               0.7332      0.2626
# 4             good-bad           0.9935               0.9181      0.0754
# 5  computer-technology           0.9977               0.9723      0.0254

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

def plot_word_vectors(words, model, title, ax):
    """Визуализирует векторы слов в 2D пространстве"""
    vectors = []
    labels = []

    for word in words:
        try:
            vectors.append(model.wv[word])
            labels.append(word)
        except KeyError:
            print(f"Слово '{word}' не найдено")

    if len(vectors) < 2:
        print("Недостаточно слов для визуализации")
        return

    # Применяем PCA для уменьшения размерности до 2D
    pca = PCA(n_components=2)
    vectors_2d = pca.fit_transform(vectors)

    # Создаем scatter plot
    ax.scatter(vectors_2d[:, 0], vectors_2d[:, 1])

    # Добавляем подписи
    for i, label in enumerate(labels):
        ax.annotate(label, (vectors_2d[i, 0], vectors_2d[i, 1]))

    ax.set_title(title)
    ax.grid(True, alpha=0.3)

# Создаем графики для сравнения
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Слова для визуализации
words_to_plot = ['king', 'queen', 'man', 'woman', 'paris', 'france', 'london', 'england']

plot_word_vectors(words_to_plot, cbow_model, "CBOW - Векторное пространство", ax1)
plot_word_vectors(words_to_plot, skipgram_model, "Skip-Gram - Векторное пространство", ax2)

plt.tight_layout()
plt.show()

# %%
# ЗАДАНИЕ: Создайте и визуализируйте тематические кластеры

def create_and_plot_clusters(word_groups, model, title):
    """Создает визуализацию для тематических групп слов"""
    all_words = []
    colors = []
    color_map = {}

    # Создаем список всех слов и их цветов
    for i, (theme, words) in enumerate(word_groups.items()):
        color_map[theme] = f'C{i}'  # автоматическое назначение цвета
        for word in words:
            all_words.append(word)
            colors.append(color_map[theme])

    # Получаем векторы
    vectors = []
    valid_words = []
    valid_colors = []

    for word, color in zip(all_words, colors):
        try:
            vectors.append(model.wv[word])
            valid_words.append(word)
            valid_colors.append(color)
        except KeyError:
            continue

    if len(vectors) < 2:
        print("Недостаточно слов для визуализации")

    # PCA для 2D
    pca = PCA(n_components=2)
    vectors_2d = pca.fit_transform(vectors)

    # Визуализация
    plt.figure(figsize=(12, 8))
    scatter = plt.scatter(vectors_2d[:, 0], vectors_2d[:, 1], c=valid_colors, alpha=0.7)

    # Подписи
    for i, word in enumerate(valid_words):
        plt.annotate(word, (vectors_2d[i, 0], vectors_2d[i, 1]), alpha=0.8)

    # Легенда
    legend_elements = [plt.Line2D([0], [0], marker='o', color='w',
                      markerfacecolor=color, markersize=10, label=theme)
                      for theme, color in color_map.items()]
    plt.legend(handles=legend_elements)

    plt.title(title)
    plt.grid(True, alpha=0.3)
    plt.show()

# Пример тематических групп
thematic_groups = {
    'страны': ['france', 'germany', 'italy', 'spain', 'england'],
    'города': ['paris', 'london', 'rome', 'berlin', 'madrid'],
    'политика': ['government', 'president', 'election', 'minister', 'congress'],
    'технологии': ['computer', 'system', 'program', 'data', 'information']
}

# Создайте визуализации для обеих моделей
print("CBOW - Тематические кластеры:")
create_and_plot_clusters(thematic_groups, cbow_model, "CBOW - Тематические кластеры")

print("Skip-Gram - Тематические кластеры:")
create_and_plot_clusters(thematic_groups, skipgram_model, "Skip-gram - Тематические кластеры")

# Ваш код здесь:


# Создайте свои тематические группы (например: еда, спорт, наука)
# создаю свои тематические группы
thematic_groups_m = {
    'еда': ['banana', 'potato', 'pizza', 'orange'],
    'спорт': ['football', 'basketball','tennis', 'volleyball'],
    'наука': ['philosophy','physics', 'chemistry','mathematics']
}
# Ваш код здесь:
# вывожу визуализация новых тематический групп
print("CBOW - Тематические кластеры:")
create_and_plot_clusters(thematic_groups_m, cbow_model, "CBOW - Тематические кластеры")
print("Skip-Gram - Тематические кластеры:")
create_and_plot_clusters(thematic_groups_m, skipgram_model, "Skip-gram - Тематические кластеры")
# Out:
# CBOW - Тематические кластеры:
# Skip-Gram - Тематические кластеры:
# CBOW - Тематические кластеры:
# Skip-Gram - Тематические кластеры:

# %%
# ЗАДАНИЕ: Проанализируйте влияние размера окна на качество векторов
import numpy as np

def test_window_sizes(window_sizes):
    """Тестирует разные размеры окон контекста"""
    results = []

    for window_size in window_sizes:
        print(f"Обучение модели с window={window_size}...")

        model = Word2Vec(
            sentences=processed_sentences,
            vector_size=100,
            window=window_size,
            min_count=2,
            workers=4,
            sg=1  # Skip-Gram
        )

        # Тестируем на нескольких парах
        test_pairs = [('king', 'queen'), ('man', 'woman'), ('paris', 'france')]
        similarities = []

        for word1, word2 in test_pairs:
            try:
                sim = model.wv.similarity(word1, word2)
                similarities.append(sim)
            except KeyError:
                similarities.append(0)

        avg_similarity = np.mean(similarities)
        results.append({
            'window_size': window_size,
            'avg_similarity': round(avg_similarity, 4),
            'vocab_size': len(model.wv.key_to_index)
        })

        print(f"  Среднее сходство: {avg_similarity:.4f}")

    return pd.DataFrame(results)

# Протестируйте разные размеры окон
window_sizes = [2, 5, 10]
results_df = test_window_sizes(window_sizes)
print("\nРезультаты тестирования размеров окон:")
print(results_df)

# Какой размер окна работает лучше?
# лучше всего работает размер окна 2, потому что при таком размере показатель сходства слов,
# которые действительно схожи (они же были выбраны специально), является наиболее высоким (ближе к 1)
# чем больше размер окна, тем результаты менее точны (показатель схожести снижается)

# Протестируйте все остальные параметры
# Out:
# Обучение модели с window=2...
#   Среднее сходство: 0.9094
# Обучение модели с window=5...
#   Среднее сходство: 0.8531
# Обучение модели с window=10...
#   Среднее сходство: 0.7773
#
# Результаты тестирования размеров окон:
#    window_size  avg_similarity  vocab_size
# 0            2          0.9094       26096
# 1            5          0.8531       26096
# 2           10          0.7773       26096

# %%
import numpy as np

def test_vector_sizes(vector_sizes):
    """Тестирует разные размерности векторов"""
    results = []

    for vector_sizee in vector_sizes:
        print(f"Обучение модели с vector ={vector_sizee}...")

        model = Word2Vec(
            sentences=processed_sentences,
            vector_size=vector_sizee,
            window=2,
            min_count=2,
            workers=4,
            sg=1  # Skip-Gram
        )

        # Тестируем на нескольких парах
        test_pairs = [('king', 'queen'), ('man', 'woman'), ('paris', 'france')]
        similarities = []

        for word1, word2 in test_pairs:
            try:
                sim = model.wv.similarity(word1, word2)
                similarities.append(sim)
            except KeyError:
                similarities.append(0)

        avg_similarity = np.mean(similarities)
        results.append({
            'vector_size': vector_sizee,
            'avg_similarity': round(avg_similarity, 4),
            'vocab_size': len(model.wv.key_to_index)
        })

        print(f"  Среднее сходство: {avg_similarity:.4f}")

    return pd.DataFrame(results)

# Протестируйте разную размерность векторов
vector_sizes = [100, 150, 200]
results_df = test_vector_sizes(vector_sizes)
print("\nРезультаты тестирования размерности векторов:")
print(results_df)

# тест разной размерности векторов не дал однозначного результата
# наибольший показатель схожести получился при размере вектора 150,
# однако однозначной тендеции не наблюдается (показатель схожести не повышается при повышении размерности)
# так при размерности 200 схожесть ниже, чем при размерности 150
# Out:
# Обучение модели с vector =100...
#   Среднее сходство: 0.9137
# Обучение модели с vector =150...
#   Среднее сходство: 0.9290
# Обучение модели с vector =200...
#   Среднее сходство: 0.9205
#
# Результаты тестирования размерности векторов:
#    vector_size  avg_similarity  vocab_size
# 0          100          0.9137       26096
# 1          150          0.9290       26096
# 2          200          0.9205       26096

# %%
import numpy as np

def test_min_count(min_counts):
    """Тестирует разную частоту слов"""
    results = []

    for min_countt in min_counts:
        print(f"Обучение модели с min_count ={min_countt}...")

        model = Word2Vec(
            sentences=processed_sentences,
            vector_size=100,
            window=2,
            min_count=min_countt,
            workers=4,
            sg=1  # Skip-Gram
        )

        # Тестируем на нескольких парах
        test_pairs = [('king', 'queen'), ('man', 'woman'), ('paris', 'france')]
        similarities = []

        for word1, word2 in test_pairs:
            try:
                sim = model.wv.similarity(word1, word2)
                similarities.append(sim)
            except KeyError:
                similarities.append(0)

        avg_similarity = np.mean(similarities)
        results.append({
            'min_count': min_countt,
            'avg_similarity': round(avg_similarity, 4),
            'vocab_size': len(model.wv.key_to_index)
        })

        print(f"  Среднее сходство: {avg_similarity:.4f}")

    return pd.DataFrame(results)

# Протестируйте разную минимальную частоту слова
min_counts = [2, 3, 4]
results_df = test_min_count(min_counts)
print("\nРезультаты тестирования частоты слов:")
print(results_df)

# тест минимальной частоты показал, что от повышения минимальной частоты вхождения слова показатель схожести уменьшается
# модель дает наиболее точные результаты при наименьшем показателе минимальной частоты вхождения (при 2)
# Out:
# Обучение модели с min_count =2...
#   Среднее сходство: 0.9258
# Обучение модели с min_count =3...
#   Среднее сходство: 0.9124
# Обучение модели с min_count =4...
#   Среднее сходство: 0.8983
#
# Результаты тестирования частоты слов:
#    min_count  avg_similarity  vocab_size
# 0          2          0.9258       26096
# 1          3          0.9124       19465
# 2          4          0.8983       15816

# %%
import numpy as np

def test_workers(workerss):
    """Тестирует разное количество ядер"""
    results = []

    for workers_ in workerss:
        print(f"Обучение модели с workers={workers_}...")

        model = Word2Vec(
            sentences=processed_sentences,
            vector_size=100,
            window=2,
            min_count=2,
            workers=workers_,
            sg=1  # Skip-Gram
        )

        # Тестируем на нескольких парах
        test_pairs = [('king', 'queen'), ('man', 'woman'), ('paris', 'france')]
        similarities = []

        for word1, word2 in test_pairs:
            try:
                sim = model.wv.similarity(word1, word2)
                similarities.append(sim)
            except KeyError:
                similarities.append(0)

        avg_similarity = np.mean(similarities)
        results.append({
            'workers': workers_,
            'avg_similarity': round(avg_similarity, 4),
            'vocab_size': len(model.wv.key_to_index)
        })

        print(f"  Среднее сходство: {avg_similarity:.4f}")

    return pd.DataFrame(results)

# Протестируйте разное количество ядер
workerss = [4, 6, 8]
results_df = test_workers(workerss)
print("\nРезультаты тестирования количества ядер:")
print(results_df)

# тест количества ядер показал, что при увеличении количества ядер, точность результата тоже увеличивается
# Out:
# Обучение модели с workers=4...
#   Среднее сходство: 0.9069
# Обучение модели с workers=6...
#   Среднее сходство: 0.9177
# Обучение модели с workers=8...
#   Среднее сходство: 0.9287
#
# Результаты тестирования количества ядер:
#    workers  avg_similarity  vocab_size
# 0        4          0.9069       26096
# 1        6          0.9177       26096
# 2        8          0.9287       26096

# %% [markdown]
# Размер окна зависит от задачи:
#
# - Синтаксис/морфология: окно 2-3
#
# - Семантика/аналогии: окно 3-5
#
# - Темы/документы: окно 5-10
